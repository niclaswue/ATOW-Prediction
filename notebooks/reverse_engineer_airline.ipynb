# %%
import pandas as pd
df = pd.read_csv("/home/wues_ni/Projects/ATOW-Prediction/data/challenge_set.csv")

df["unique_aircraft"] = df["aircraft_type"] + "_" + df["airline"]
df["unique_aircraft"].value_counts()[80:]
# Out:
# unique_aircraft
# A320_3a6435cd8884f0dd51b886b3e57267f3    94
# B788_4fea233a1f67230add909d3e8fc8e230    63
# B789_4fea233a1f67230add909d3e8fc8e230    47
# BCS3_1332254e11e92b4ac6410613b2e86787    33
# B772_a73f82288988b79be490c6322f4c32ed    30
# AT76_a73f82288988b79be490c6322f4c32ed    20
# B738_5ab5177074e7490ebf8c249ce250759e    14
# A320_36b364c9ba9ffb2e3e4803cb4e025745    13
# B737_f5c2e765e074db66052862ab3d1c4529    11
# A320_713b84080a5509415d149fe1f7f0add1     9
# B752_a73f82288988b79be490c6322f4c32ed     6
# B738_4fea233a1f67230add909d3e8fc8e230     5
# B737_5ab5177074e7490ebf8c249ce250759e     4
# B737_b37a3f3161e6ec4cffbb65e7ebf4ecfe     4
# B738_310d41975a1e6b9b51ca356414d67daf     3
# B38M_5ab5177074e7490ebf8c249ce250759e     3
# B738_b37a3f3161e6ec4cffbb65e7ebf4ecfe     3
# CRJ9_36b364c9ba9ffb2e3e4803cb4e025745     3
# B737_6351ec1b849adacc0cbb3b1313d8d39b     2
# A310_6351ec1b849adacc0cbb3b1313d8d39b     2
# A332_588c4a7c5b7320c61a6c4227be465964     2
# ...

# %%
# most common route per airline
df["unique_route"] = df["adep"] + "_" + df["ades"]
for al in df["airline"].unique():
    print("-"* 10)
    print(al)
    print(df[df["airline"] == al]["unique_route"].value_counts()[:5])
# Out:
# ----------
# a73f82288988b79be490c6322f4c32ed
# unique_route
# EGLL_EIDW    2157
# EIDW_EGLL    2149
# EGKK_EIDW    1030
# EIDW_EGKK    1015
# LFPG_EIDW     928
# Name: count, dtype: int64
# ----------
# 5543e4dc327359ffaf5b9c0e6faaf0e1
# unique_route
# KJFK_EGLL    763
# EGLL_KJFK    750
# KDFW_EGLL    664
# EGLL_KDFW    608
# EGLL_KORD    565
# Name: count, dtype: int64
# ----------
# 8be5c854fd664bcb97fb543339f74770
# unique_route
# ENGM_EKCH    1865
# EKCH_ENGM    1843
# ENBR_ENGM    1727
# ESSA_EKCH    1722
# EKCH_ESSA    1719
# Name: count, dtype: int64
# ----------
# 6351ec1b849adacc0cbb3b1313d8d39b
# unique_route
# LLBG_LTFM    1422
# LTFM_LLBG    1324
# LTFM_LFPG    1135
# LTFM_LTAC    1112
# LFPG_LTFM    1097
# Name: count, dtype: int64
# ----------
# 5d407cb11cc29578cc3e292e743f5393
# unique_route
# LOWW_LSZH    1186
# LOWW_EDDB    1170
# LSZH_LOWW    1103
# EDDB_LOWW    1080
# EDDF_LOWW    1067
# Name: count, dtype: int64
# ----------
# 2d5def0a5a844b343ba1b7cc9cb28fa9
# ...

# %%
# most common aircraft per airline
for al in df["airline"].unique():
    print("-"* 10)
    print(al)
    print(df[df["airline"] == al]["aircraft_type"].value_counts()[:5])
# Out:
# ----------
# a73f82288988b79be490c6322f4c32ed
# aircraft_type
# A320    28284
# A333     4249
# A21N     4190
# A20N      712
# B772       30
# Name: count, dtype: int64
# ----------
# 5543e4dc327359ffaf5b9c0e6faaf0e1
# aircraft_type
# B772    7447
# B788    4358
# B77W    3623
# B789    3050
# B773       1
# Name: count, dtype: int64
# ----------
# 8be5c854fd664bcb97fb543339f74770
# aircraft_type
# A20N    28159
# CRJ9    18316
# A320     5844
# AT76     5791
# B737     2793
# Name: count, dtype: int64
# ----------
# 6351ec1b849adacc0cbb3b1313d8d39b
# aircraft_type
# A321    17607
# B738    17474
# A21N    16505
# A333     7572
# B38M     4619
# Name: count, dtype: int64
# ----------
# 5d407cb11cc29578cc3e292e743f5393
# aircraft_type
# E195    22330
# A320    22227
# A321     4388
# B763      856
# B772      845
# Name: count, dtype: int64
# ----------
# 2d5def0a5a844b343ba1b7cc9cb28fa9
# aircraft_type
# BCS3    10325
# A320     6914
# A20N     5543
# A321     5026
# BCS1     4649
# ...

# %%
A320_a73f82288988b79be490c6322f4c32ed    => Aer Lingus A320 (https://www.seatguru.com/airlines/Aer_Lingus/Aer_Lingus_Airbus_A320.php)
A20N_8be5c854fd664bcb97fb543339f74770    => SAS A320neo (https://www.sasgroup.net/about-sas/the-fleet/a320neo-a321lr/)

# %%
A320_a73f82288988b79be490c6322f4c32ed    28284 => Aer Lingus A320 (https://www.seatguru.com/airlines/Aer_Lingus/Aer_Lingus_Airbus_A320.php) https://oneworldvirtual.org/fleet/models/aer-lingus-airbus-a320-214
A20N_8be5c854fd664bcb97fb543339f74770    28159 => SAS A320neo (https://www.sasgroup.net/about-sas/the-fleet/a320neo-a321lr/)
E195_5d407cb11cc29578cc3e292e743f5393    22330 => Austrian Embrayer 195 (https://www.austrian.com/de/de/embraer-195)
A320_5d407cb11cc29578cc3e292e743f5393    22227 => Austrian A320 (https://www.austrian.com/de/de/airbus-a320-200)
CRJ9_8be5c854fd664bcb97fb543339f74770    18316 => SAS CRJ9 (https://www.sasgroup.net/about-sas/the-fleet/crj900/)
A321_6351ec1b849adacc0cbb3b1313d8d39b    17607 => Turkish A321 (https://www.turkishairlines.com/de-de/flights/fly-different/fleet/airbus-a321-200/)
B738_6351ec1b849adacc0cbb3b1313d8d39b    17474 => Turkish B738 (https://www.seatguru.com/airlines/Turkish_Airlines/Turkish_Airlines_Boeing_737-800_B.php)
A21N_6351ec1b849adacc0cbb3b1313d8d39b    16505 => Turkish A21N (https://www.seatguru.com/airlines/Turkish_Airlines/Turkish_Airlines_Airbus_A321neo.php) https://staralliancevirtual.org/fleet/models/turkish-airlines-airbus-a321-271nx
A319_bdeeef3a675587d530de70a25d7118d2    15559 => Brussels Airlines A319 (https://www.brusselsairlines.com/de/de/flying-with-us/our-fleet/airbus-a319)
A320_bdeeef3a675587d530de70a25d7118d2    13780 => Brussels A320 (https://www.brusselsairlines.com/de/de/flying-with-us/our-fleet/airbus-a320)
BCS3_2d5def0a5a844b343ba1b7cc9cb28fa9    10325 => Swiss Air (https://www.swiss.com/de/de/discover/fleet/airbus-shorthaul#3) https://staralliancevirtual.org/fleet/models/swiss-airbus-a220-300 
B738_3922524069809ac4326134429751e26f     8769 => Jet2 (https://jethroseu.co.uk/fleets/fleet_listings/jet2_b738.htm)
A333_6351ec1b849adacc0cbb3b1313d8d39b     7572 => Turkish https://staralliancevirtual.org/fleet/models/turkish-airlines-airbus-a330-343
B772_5543e4dc327359ffaf5b9c0e6faaf0e1     7447 => American Airlines (https://oneworldvirtual.org/fleet/models/american-airlines-boeing-777-223-er)
A320_2d5def0a5a844b343ba1b7cc9cb28fa9     6914 => Swiss Air (https://www.swiss.com/de/de/discover/fleet/airbus-shorthaul#2)
A320_8be5c854fd664bcb97fb543339f74770     5844 => SAS https://www.sasgroup.net/about-sas/the-fleet/airbus-a319-a320/
AT76_8be5c854fd664bcb97fb543339f74770     5791 => SAS https://www.sasgroup.net/about-sas/the-fleet/atr-72-600/
B738_f5c2e765e074db66052862ab3d1c4529     5642 => TuiFly Deutschland? https://www.tui.com/service-kontakt/flug/50-jahre-tui-fly-jubilaeum/die-flotte
A20N_2d5def0a5a844b343ba1b7cc9cb28fa9     5543 => Swiss Air
A321_2d5def0a5a844b343ba1b7cc9cb28fa9     5026 => Swiss Air
BCS1_2d5def0a5a844b343ba1b7cc9cb28fa9    4649 => Swiss Air
B38M_6351ec1b849adacc0cbb3b1313d8d39b    4619 => Turkish
CRJ9_1332254e11e92b4ac6410613b2e86787    4606 => SAS (Cityjet)
A321_5d407cb11cc29578cc3e292e743f5393    4388 => Austrian
B788_5543e4dc327359ffaf5b9c0e6faaf0e1    4358 => American
B77W_6351ec1b849adacc0cbb3b1313d8d39b    4325 => Turkish
A333_a73f82288988b79be490c6322f4c32ed    4249 => Aer Lingus https://oneworldvirtual.org/fleet/models/aer-lingus-airbus-a330-302
A21N_a73f82288988b79be490c6322f4c32ed    4190 => Aer Lingus
B38M_3922524069809ac4326134429751e26f    4160 => Jet2
B77W_5543e4dc327359ffaf5b9c0e6faaf0e1    3623 => American
B789_5543e4dc327359ffaf5b9c0e6faaf0e1    3050 => American
A20N_1332254e11e92b4ac6410613b2e86787    2998 => SAS (Cityjet)
B737_8be5c854fd664bcb97fb543339f74770    2793 => SAS
A321_8be5c854fd664bcb97fb543339f74770    2401 => SAS
A333_2d5def0a5a844b343ba1b7cc9cb28fa9    2375 => Swiss Air
E195_8be5c854fd664bcb97fb543339f74770    2268 => SAS
A332_6351ec1b849adacc0cbb3b1313d8d39b    2239 => Turkish
B789_6351ec1b849adacc0cbb3b1313d8d39b    2222 => Turkish
B738_f53c55b5cf0cbb3be755bf50df6fa52d    2130 => TuiFly
E190_f53c55b5cf0cbb3be755bf50df6fa52d    2105 => TuiFly
A333_8be5c854fd664bcb97fb543339f74770    1934 => SAS
B789_4fea233a1f67230add909d3e8fc8e230    47 => TuiFly Nordic
BCS3_1332254e11e92b4ac6410613b2e86787    33 => SAS (Cityjet)
B772_a73f82288988b79be490c6322f4c32ed    30 => Aer Lingus
AT76_a73f82288988b79be490c6322f4c32ed    20 => Aer Lingus
B738_5ab5177074e7490ebf8c249ce250759e    14 => Transavia
A320_36b364c9ba9ffb2e3e4803cb4e025745    13 => Air Baltic / Brussels
B737_f5c2e765e074db66052862ab3d1c4529    11 => TuiFly Deutschland?
A320_713b84080a5509415d149fe1f7f0add1     9
B752_a73f82288988b79be490c6322f4c32ed     6 => Aer Lingus
B738_4fea233a1f67230add909d3e8fc8e230     5 => TuiFly Nordic
B737_5ab5177074e7490ebf8c249ce250759e     4 => Transavia
B737_b37a3f3161e6ec4cffbb65e7ebf4ecfe     4
B738_310d41975a1e6b9b51ca356414d67daf     3
B38M_5ab5177074e7490ebf8c249ce250759e     3 => Transavia
B738_b37a3f3161e6ec4cffbb65e7ebf4ecfe     3
CRJ9_36b364c9ba9ffb2e3e4803cb4e025745     3 => Air Baltic / Brussels
B737_6351ec1b849adacc0cbb3b1313d8d39b     2 => Turkish
A310_6351ec1b849adacc0cbb3b1313d8d39b     2 => Turkish
A332_588c4a7c5b7320c61a6c4227be465964     2
B738_415bb6c2faf8f0aa7b4108deeec9869c     1
A320_ecae30f8b0a678b4e97d1f7307642d2b     1
E290_2d5def0a5a844b343ba1b7cc9cb28fa9     1 => Swiss Air
CRJ9_154acc473ac7d5991245125f4ff6b3a6     1
A321_a73f82288988b79be490c6322f4c32ed     1 => Aer Lingus
B738_2d5def0a5a844b343ba1b7cc9cb28fa9     1 => Swiss Air
B738_6a681ee572c1e4e981cdab3c55b4b422     1
B738_cc0752e0930c0f501873a342d96c13f0     1
B738_72ba06dd5ae13526df103042ce4c535e     1
B773_5543e4dc327359ffaf5b9c0e6faaf0e1     1 => American
C56X_36b364c9ba9ffb2e3e4803cb4e025745     1 => Air Baltic / Brussels

# %%
df[df["airline"] == "36b364c9ba9ffb2e3e4803cb4e025745"].sample(5)
# Out:
#         flight_id        date                          callsign  adep  \
# 365901  257937306  2022-12-25  82563a083626081b0c97bbd71f8f7f7e  EBBR
# 237301  254959338  2022-09-02  4bc8fe1f243318b67a87d30036c289f0  LSZH
# 324505  256984281  2022-11-13  82563a083626081b0c97bbd71f8f7f7e  EBBR
# 345235  257446573  2022-12-04  82563a083626081b0c97bbd71f8f7f7e  EBBR
# 316958  256807455  2022-11-06  82563a083626081b0c97bbd71f8f7f7e  EBBR
#
#        name_adep country_code_adep  ades name_ades country_code_ades  \
# 365901  Brussels                BE  LLBG  Tel Aviv                IL
# 237301    Zurich                CH  LFMN      Nice                FR
# 324505  Brussels                BE  LLBG  Tel Aviv                IL
# 345235  Brussels                BE  LLBG  Tel Aviv                IL
# 316958  Brussels                BE  LLBG  Tel Aviv                IL
#
#         actual_offblock_time          arrival_time aircraft_type wtc  \
# ...
